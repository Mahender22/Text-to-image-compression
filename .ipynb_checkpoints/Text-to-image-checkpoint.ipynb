# %%
import os
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
import random

# %%
# # 10 images 0 to 9 - 1 each
# img_path = r'C:\Users\Mahender\Documents\MS docs\Final docs\Rowan University\sem4\ADV topics in DS LLM\Project\Text-to-image-for-compression\Data\Data-10-images'

# 10 images of 1
img_path = r'C:\Users\Mahender\Documents\MS docs\Final docs\Rowan University\sem4\ADV topics in DS LLM\Project\Text-to-image-for-compression\Data\Data-10-images-1'

# # All images of 1 - 10772 images
# img_path = r'C:\Users\Mahender\Documents\MS docs\Final docs\Rowan University\sem4\ADV topics in DS LLM\Project\Text-to-image-for-compression\Data\dataset\1\1'

image_extension = '.png'

data = []

# Loop through all directories and subdirectories
for root, dirs, files in os.walk(img_path):
    for file in files:
        if file.lower()[-3:] == 'png':
            file_path = os.path.join(root, file)
            try:
                img = Image.open(file_path)                
                # If the image is in RGBA, convert transparent pixels to white
                if img.mode == 'RGBA':
                    white_bg = Image.new('RGB', img.size, (255, 255, 255))
                    white_bg.paste(img, mask=img.split()[3])
                    # Convert the image to grayscale (L mode)
                    img = white_bg.convert('L')    
                    
                img_data = np.array(img)
                label = file_path.split('\\')[-1]
                data.append({"label": label, "image_data": img_data})
            except Exception as e:
                print(f"Error opening {file_path}: {e}")

df = pd.DataFrame(data)
print(df.head())
# Out:
#      label                                         image_data
# 0  100.png  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...
# 1  101.png  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...
# 2  102.png  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...
# 3  103.png  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...
# 4  104.png  [[255, 255, 255, 255, 255, 255, 255, 255, 255,...

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Extract labels from the dataframe
labels = df['label'].values

# Convert the labels to one-hot encoding
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(labels)

# onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
onehot_encoder = OneHotEncoder()
onehot_encoded = onehot_encoder.fit_transform(integer_encoded)

# The onehot_encoded array will be used as input to the model

# %%
# Assuming all images are grayscale and of size
X = df['image_data'].values

# Normalize pixel values
X = np.array([x.flatten() / 255.0 for x in X])  # Flatten the images and normalize pixel values

# %%
# Define the model
def create_model(input_dim, output_dim):
    model = models.Sequential()
    model.add(layers.Dense(32, activation='relu', input_dim=input_dim))  # First dense layer
#     model.add(layers.Dense(512, activation='relu'))  # Hidden dense layer
#     model.add(layers.Dense(1024, activation='relu'))  # Hidden dense layer
    model.add(layers.Dense(32, activation='relu'))  # Hidden dense layer
    model.add(layers.Dense(output_dim, activation='sigmoid'))  # Output layer (flattened image)
    return model

# Assume one-hot encoded labels have shape (num_samples, num_labels)
input_dim = onehot_encoded.shape[1]
output_dim = 28 * 28

model = create_model(input_dim, output_dim)

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                352
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 784)               25872
#
# =================================================================
# Total params: 27,280
# Trainable params: 27,280
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
model.fit(onehot_encoded, X, epochs=120, batch_size=64)
# Out:
# Epoch 1/120
# 1/1 [==============================] - 1s 510ms/step - loss: 0.2452 - accuracy: 0.0000e+00
# Epoch 2/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2446 - accuracy: 0.0000e+00
# Epoch 3/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2439 - accuracy: 0.0000e+00
# Epoch 4/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2432 - accuracy: 0.0000e+00
# Epoch 5/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2425 - accuracy: 0.0000e+00
# Epoch 6/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2418 - accuracy: 0.0000e+00
# Epoch 7/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2410 - accuracy: 0.0000e+00
# Epoch 8/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2402 - accuracy: 0.0000e+00
# Epoch 9/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2394 - accuracy: 0.0000e+00
# Epoch 10/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2385 - accuracy: 0.0000e+00
# Epoch 11/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2375 - accuracy: 0.0000e+00
# Epoch 12/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2366 - accuracy: 0.0000e+00
# Epoch 13/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2355 - accuracy: 0.0000e+00
# Epoch 14/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2344 - accuracy: 0.0000e+00
# Epoch 15/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2333 - accuracy: 0.0000e+00
# Epoch 16/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.0000e+00
# Epoch 17/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2308 - accuracy: 0.0000e+00
# Epoch 18/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2295 - accuracy: 0.0000e+00
# Epoch 19/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2281 - accuracy: 0.0000e+00
# Epoch 20/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2266 - accuracy: 0.0000e+00
# Epoch 21/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2251 - accuracy: 0.0000e+00
# Epoch 22/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2234 - accuracy: 0.0000e+00
# Epoch 23/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2217 - accuracy: 0.0000e+00
# Epoch 24/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2199 - accuracy: 0.0000e+00
# Epoch 25/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2180 - accuracy: 0.0000e+00
# Epoch 26/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2161 - accuracy: 0.0000e+00
# Epoch 27/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2140 - accuracy: 0.0000e+00
# Epoch 28/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2118 - accuracy: 0.0000e+00
# Epoch 29/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2096 - accuracy: 0.0000e+00
# Epoch 30/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2072 - accuracy: 0.0000e+00
# Epoch 31/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2047 - accuracy: 0.0000e+00
# Epoch 32/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2021 - accuracy: 0.0000e+00
# Epoch 33/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1995 - accuracy: 0.0000e+00
# Epoch 34/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1967 - accuracy: 0.0000e+00
# Epoch 35/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.0000e+00
# Epoch 36/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1908 - accuracy: 0.0000e+00
# Epoch 37/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1877 - accuracy: 0.0000e+00
# Epoch 38/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1845 - accuracy: 0.0000e+00
# Epoch 39/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1812 - accuracy: 0.0000e+00
# Epoch 40/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.0000e+00
# Epoch 41/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1742 - accuracy: 0.0000e+00
# Epoch 42/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1706 - accuracy: 0.0000e+00
# Epoch 43/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1669 - accuracy: 0.0000e+00
# Epoch 44/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1631 - accuracy: 0.0000e+00
# Epoch 45/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1593 - accuracy: 0.0000e+00
# Epoch 46/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1554 - accuracy: 0.0000e+00
# Epoch 47/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1514 - accuracy: 0.0000e+00
# Epoch 48/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1473 - accuracy: 0.0000e+00
# Epoch 49/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1433 - accuracy: 0.0000e+00
# Epoch 50/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.0000e+00
# Epoch 51/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1350 - accuracy: 0.0000e+00
# Epoch 52/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1309 - accuracy: 0.0000e+00
# Epoch 53/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1267 - accuracy: 0.0000e+00
# Epoch 54/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1226 - accuracy: 0.0000e+00
# Epoch 55/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1184 - accuracy: 0.0000e+00
# Epoch 56/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1143 - accuracy: 0.0000e+00
# Epoch 57/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1103 - accuracy: 0.0000e+00
# Epoch 58/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1063 - accuracy: 0.0000e+00
# Epoch 59/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1023 - accuracy: 0.0000e+00
# Epoch 60/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0984 - accuracy: 0.0000e+00
# Epoch 61/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.0000e+00
# Epoch 62/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0909 - accuracy: 0.0000e+00
# Epoch 63/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.0000e+00
# Epoch 64/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0838 - accuracy: 0.0000e+00
# Epoch 65/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0804 - accuracy: 0.0000e+00
# Epoch 66/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0771 - accuracy: 0.0000e+00
# Epoch 67/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.0000e+00
# Epoch 68/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0709 - accuracy: 0.0000e+00
# Epoch 69/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0681 - accuracy: 0.0000e+00
# Epoch 70/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0653 - accuracy: 0.0000e+00
# Epoch 71/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.0000e+00
# Epoch 72/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.0000e+00
# Epoch 73/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0579 - accuracy: 0.0000e+00
# Epoch 74/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0557 - accuracy: 0.0000e+00
# Epoch 75/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.0000e+00
# Epoch 76/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0517 - accuracy: 0.0000e+00
# Epoch 77/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0499 - accuracy: 0.0000e+00
# Epoch 78/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0482 - accuracy: 0.0000e+00
# Epoch 79/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0466 - accuracy: 0.0000e+00
# Epoch 80/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 0.0000e+00
# Epoch 81/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0438 - accuracy: 0.0000e+00
# Epoch 82/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0425 - accuracy: 0.0000e+00
# Epoch 83/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 0.0000e+00
# Epoch 84/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.0000e+00
# Epoch 85/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.0000e+00
# Epoch 86/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0383 - accuracy: 0.0000e+00
# Epoch 87/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0374 - accuracy: 0.0000e+00
# Epoch 88/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 0.0000e+00
# Epoch 89/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0359 - accuracy: 0.0000e+00
# Epoch 90/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.0000e+00
# Epoch 91/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.0000e+00
# Epoch 92/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0339 - accuracy: 0.0000e+00
# Epoch 93/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.0000e+00
# Epoch 94/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.0000e+00
# Epoch 95/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 0.0000e+00
# Epoch 96/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 0.0000e+00
# Epoch 97/120
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 0.0000e+00
# Epoch 98/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.0000e+00
# Epoch 99/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.0000e+00
# Epoch 100/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.0000e+00
# Epoch 101/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.0000e+00
# Epoch 102/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.0000e+00
# Epoch 103/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0296 - accuracy: 0.0000e+00
# Epoch 104/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 0.0000e+00
# Epoch 105/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.0000e+00
# Epoch 106/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.0000e+00
# Epoch 107/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.0000e+00
# Epoch 108/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.0000e+00
# Epoch 109/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 0.0000e+00
# Epoch 110/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.0000e+00
# Epoch 111/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 0.0000e+00
# Epoch 112/120
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0277 - accuracy: 0.0000e+00
# Epoch 113/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.0000e+00
# Epoch 114/120
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0274 - accuracy: 0.0000e+00
# Epoch 115/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.0000e+00
# Epoch 116/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.0000e+00
# Epoch 117/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.0000e+00
# Epoch 118/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.0000e+00
# Epoch 119/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 0.0000e+00
# Epoch 120/120
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.0000e+00

# %%
# # Function to get the original image data from the DataFrame
# def get_original_image_from_df(label, df):
#     # Locate the row in the DataFrame that matches the label
#     row = df[df['label'] == label]
#     if not row.empty:
#         return row['image_data'].values[0]  # Get the image data
#     else:
#         print("Label not found in DataFrame.")
#         return None

# # Make a prediction
# labels_to_predict = df['label'].values
# for label in labels_to_predict:
#     encoded_label = onehot_encoder.transform([[label_encoder.transform([label])[0]]])
#     predicted_image = model.predict(encoded_label)

#     # Reshape and visualize the predicted image
#     predicted_image = predicted_image.reshape((28, 28))

#     # Get the original image from the DataFrame
#     original_image = get_original_image_from_df(label, df)

#     # Set up the plot
#     plt.figure(figsize=(10, 5))

#     # Plot original image
#     plt.subplot(1, 2, 1)
#     plt.imshow(original_image, cmap='gray')
#     plt.title('Original Image')
#     plt.axis('off')  # Hide axis

#     # Plot predicted image
#     plt.subplot(1, 2, 2)
#     plt.imshow(predicted_image, cmap='gray')
#     plt.title('Predicted Image')
#     plt.axis('off')  # Hide axis

#     plt.show()

# %%
save_path = r'C:\Users\Mahender\Documents\MS docs\Final docs\Rowan University\sem4\ADV topics in DS LLM\Project\Text-to-image-for-compression\saved_models'

model.save(save_path + '\\nn-10-1.h5')  # Save as HDF5 file

# %%
# model = tf.keras.models.load_model('\\nn-10-1.h5')

# %%
def pixel_accuracy(original, predicted):
    """
    Calculate pixel accuracy based on the mean absolute error between the original and predicted images.

    Parameters:
    original (np.array): The original image array (shape: height x width).
    predicted (np.array): The predicted image array (shape: height x width).

    Returns:
    float: The pixel accuracy as a percentage.
    """
    original = np.array(original)
    predicted = np.array(predicted)
    
    # Check if the shapes match
    if original.shape != predicted.shape:
        raise ValueError("Original and predicted images must have the same shape.")
    
    # Calculate the mean absolute error
    mae = np.mean(np.abs(original - predicted))

    # Convert MAE to a percentage accuracy (assuming pixel values are in [0, 255])
    max_mae = 255
    accuracy = 100 * (1 - (mae / max_mae))  # Normalize accuracy to be between 0 and 100

    return accuracy  # Return as percentage

# Function to get the original image data from the DataFrame
def get_original_image_from_df(label, df):
    # Locate the row in the DataFrame that matches the label
    row = df[df['label'] == label]
    if not row.empty:
        return row['image_data'].values[0]  # Get the image data
    else:
        print("Label not found in DataFrame.")
        return None

# List to hold pixel accuracy values for all predictions
all_accuracies = []

# Make a prediction
# labels_to_predict = df['label'].values
labels_to_predict = random.sample(list(df['label'].values), 10)

for label in labels_to_predict:
    encoded_label = onehot_encoder.transform([[label_encoder.transform([label])[0]]])
    predicted_image = model.predict(encoded_label)

    # Reshape the predicted image and unnormalize it (convert back to 0-255 range)
    predicted_image = predicted_image.reshape((28, 28))
    predicted_image = predicted_image * 255.0  # Unnormalize the predicted image

    # Get the original image from the DataFrame
    original_image = get_original_image_from_df(label, df)

    # Check if original image is not None
    if original_image is not None:
        # Calculate pixel accuracy
        accuracy = pixel_accuracy(original_image, predicted_image)
        all_accuracies.append(accuracy)
        print(f"Pixel Accuracy for label '{label}': {accuracy:.2f}%")

        # Set up the plot
        plt.figure(figsize=(10, 5))

        # Plot original image
        plt.subplot(1, 2, 1)
        plt.imshow(original_image, cmap='gray')
        plt.title('Original Image')
        plt.axis('off')  # Hide axis

        # Plot predicted image
        plt.subplot(1, 2, 2)
        plt.imshow(predicted_image, cmap='gray')
        plt.title('Predicted Image')
        plt.axis('off')  # Hide axis

        plt.show()

# Calculate and print the average pixel accuracy
average_accuracy = np.mean(all_accuracies)
print(f"\nAverage Pixel Accuracy over all above images: {average_accuracy:.2f}%")
# Out:
# 1/1 [==============================] - 0s 11ms/step
# Pixel Accuracy for label '100.png': -625.05%
# 1/1 [==============================] - 0s 11ms/step
# Pixel Accuracy for label '109.png': -441.74%
# 1/1 [==============================] - 0s 10ms/step
# Pixel Accuracy for label '108.png': -541.94%
# 1/1 [==============================] - 0s 11ms/step
# Pixel Accuracy for label '104.png': -509.54%
# 1/1 [==============================] - 0s 11ms/step
# Pixel Accuracy for label '103.png': -439.96%
# 1/1 [==============================] - 0s 10ms/step
# Pixel Accuracy for label '105.png': -641.77%
# 1/1 [==============================] - 0s 10ms/step
# Pixel Accuracy for label '107.png': -853.50%
# 1/1 [==============================] - 0s 10ms/step
# Pixel Accuracy for label '106.png': -494.40%
# 1/1 [==============================] - 0s 10ms/step
# Pixel Accuracy for label '101.png': -674.31%
# 1/1 [==============================] - 0s 9ms/step
# Pixel Accuracy for label '102.png': -508.96%
# Average Pixel Accuracy over all above images: -573.12%

# %%
# List to hold pixel accuracy values for all predictions
all_accuracies = []

# Encode all labels in the DataFrame
encoded_labels = onehot_encoder.transform([[label_encoder.transform([label])[0]] for label in df['label'].values])

# Make predictions for all encoded labels at once
predicted_images = model.predict(encoded_labels)

# Loop over all predicted images and corresponding original images
for i, label in enumerate(df['label'].values):
    predicted_image = predicted_images[i].reshape((28, 28))  # Reshape the predicted image
    predicted_image = predicted_image * 255.0  # Unnormalize the predicted image

    # Get the original image from the DataFrame
    original_image = get_original_image_from_df(label, df)

    # Check if original image is not None
    if original_image is not None:
        # Calculate pixel accuracy
        accuracy = pixel_accuracy(original_image, predicted_image)
        all_accuracies.append(accuracy)

# Calculate and print the average pixel accuracy
if all_accuracies:
    average_accuracy = np.mean(all_accuracies)
    print(f"\nAverage Pixel Accuracy over all images: {average_accuracy:.2f}%")
else:
    print("No valid images found for accuracy calculation.")
# Out:
# 1/1 [==============================] - 0s 10ms/step
#
# Average Pixel Accuracy over all images: -573.12%
